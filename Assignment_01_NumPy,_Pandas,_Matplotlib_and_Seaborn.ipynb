# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavya1234/Assignment-01---NumPy-Pandas-Matplotlib-and-Seaborn/blob/main/Assignment_01_NumPy%2C_Pandas%2C_Matplotlib_and_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment on Python for Data Science
# Do the following operation on Iris dataset:
# 1. Read the dataset to python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.
# __________________________________________________________________________________

# %% [markdown]
# **1. Read the dataset to python environment.**

# %%
import  pandas as pd
Data=pd.read_excel('/content/iris.xls')
Data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **2. Display the columns in the dataset.**

# %%
print(Data.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# **3. Calculate the mean of each column of the dataset.**

# %%
means=Data.mean()
print(means)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-5-1c9103fdbc7f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means=Data.mean()

# %% [markdown]
# **4. Check for the null values present in the dataset.**

# %%
print(Data.isnull())
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
print(Data.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# **5. Perform meaningful visualizations using the dataset. Bring at least 3**
# **visualizations.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sl_df = Data[['Classification', 'SL']] # Create a new dataframe with Sepal Length (SL) for each Classification
sl_mean_df = sl_df.groupby('Classification').mean() # Group the data by species and calculate the mean Sepal Length
plt.bar(sl_mean_df.index, sl_mean_df['SL'])# Create a bar chart using Matplotlib 
plt.xlabel('Classification') # Add labels 
plt.ylabel('Sepal Length (cm)') # Add labels 
plt.title('Mean Sepal Length of Iris Classification') # Add title 
plt.show() # Show the plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Filter the SL values of the three Classification
setosa_sl = Data[Data['Classification'] == 'Iris-setosa']['SL']
versicolor_sl = Data[Data['Classification'] == 'Iris-versicolor']['SL']
virginica_sl = Data[Data['Classification'] == 'Iris-virginica']['SL']

# Create a list of the filtered SL values
data = [setosa_sl, versicolor_sl, virginica_sl]

# Set the figure size
plt.figure(figsize=(8, 6))

# Create a box plot
plt.boxplot(data, labels=['Iris-Setosa', 'Iris-Versicolor', 'Iris-Virginica'])

# Set the plot title and axis labels
plt.title('Box plot of Sepal Length by Classification')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')

# Show the plot
plt.show()

# %%
import seaborn as sns
sns.scatterplot(data=Data, x='SL', y='PW', hue='Classification')
# Out:
# <Axes: xlabel='SL', ylabel='PW'>
